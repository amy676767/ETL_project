# %%
import requests, time
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
vehicle_urls = []


def fetch_page_and_convert_to_bs(url):

    response = requests.get(url)
    soup = bs(response.text, 'html.parser')
    
    # Delay 5 seconds before returning the soup object to prevent Python from sending too many requests in a rapid succession
    time.sleep(5)

    return soup


def get_vehicle_urls():
    
    counter = 1
    iterate = True
    pages = 0
        
    # Storing the base url the data will be fetched from
    base_url = 'https://www.cars.com/for-sale/searchresults.action/?dealerType=all&perPage=50&rd=10&searchSource=PAGINATION&sort=relevance&page='

    # Running a loop to determine how many pages with vehicle content exist
    while (iterate):
        
        """ 
            Creating a dynamic url that will update the page number in each pass of the loop
            until there is no vehicle content to be found
        """

        url = f'{base_url}{counter}'
        
        # Instantiating a beautiful soup object to store the html
        soup = fetch_page_and_convert_to_bs(url)        
        
        # Identify if any vehicles exist on the page
        has_vehicle = len(soup.find('a', class_ = 'shop-srp-listings__listing'))

        if (has_vehicle and pages < 3): # The "3" in the conditional to prevent the return of the entire cars.com list.
            pages += 1
            counter += 1
            
            # Find all the vehicles that exist on the page
            vehicles = soup.find_all('a', class_ = 'shop-srp-listings__listing')
            
            for vehicle in vehicles:
                vehicle_urls.append(vehicle['href'])
            
        else:
            iterate = False

# %%
get_vehicle_urls()
url=vehicle_urls
print(url)
# Out:
# ['/vehicledetail/detail/771429339/overview/', '/vehicledetail/detail/782675683/overview/', '/vehicledetail/detail/780786906/overview/', '/vehicledetail/detail/782874496/overview/', '/vehicledetail/detail/759906922/overview/', '/vehicledetail/detail/780786905/overview/', '/vehicledetail/detail/778814930/overview/', '/vehicledetail/detail/782110566/overview/', '/vehicledetail/detail/774253853/overview/', '/vehicledetail/detail/778078127/overview/', '/vehicledetail/detail/782118329/overview/', '/vehicledetail/detail/775693455/overview/', '/vehicledetail/detail/778177902/overview/', '/vehicledetail/detail/771301441/overview/', '/vehicledetail/detail/772928320/overview/', '/vehicledetail/detail/782512548/overview/', '/vehicledetail/detail/772428590/overview/', '/vehicledetail/detail/767362885/overview/', '/vehicledetail/detail/781052664/overview/', '/vehicledetail/detail/775382273/overview/', '/vehicledetail/detail/762192909/overview/', '/vehicledetail/detail/781551588/overview/', '/vehicledetail/detail/783450814/overview/', '/vehicledetail/detail/761679861/overview/', '/vehicledetail/detail/778851511/overview/', '/vehicledetail/detail/781721556/overview/', '/vehicledetail/detail/781888403/overview/', '/vehicledetail/detail/781286877/overview/', '/vehicledetail/detail/773674214/overview/', '/vehicledetail/detail/783450972/overview/', '/vehicledetail/detail/777172313/overview/', '/vehicledetail/detail/780444671/overview/', '/vehicledetail/detail/776975579/overview/', '/vehicledetail/detail/777666014/overview/', '/vehicledetail/detail/780568552/overview/', '/vehicledetail/detail/778939911/overview/', '/vehicledetail/detail/771878755/overview/', '/vehicledetail/detail/767173334/overview/', '/vehicledetail/detail/781721464/overview/', '/vehicledetail/detail/778673969/overview/', '/vehicledetail/detail/780331518/overview/', '/vehicledetail/detail/777185175/overview/', '/vehicledetail/detail/762232238/overview/', '/vehicledetail/detail/779962876/overview/', '/vehicledetail/detail/778374655/overview/', '/vehicledetail/detail/778563073/overview/', '/vehicledetail/detail/769014732/overview/', '/vehicledetail/detail/783383843/overview/', '/vehicledetail/detail/769029343/overview/', '/vehicledetail/detail/781765593/overview/', '/vehicledetail/detail/776365139/overview/', '/vehicledetail/detail/762219427/overview/', '/vehicledetail/detail/779065901/overview/', '/vehicledetail/detail/774457832/overview/', '/vehicledetail/detail/776178762/overview/', '/vehicledetail/detail/781303276/overview/', '/vehicledetail/detail/760093882/overview/', '/vehicledetail/detail/782675666/overview/', '/vehicledetail/detail/781303263/overview/', '/vehicledetail/detail/773295958/overview/', '/vehicledetail/detail/764870576/overview/', '/vehicledetail/detail/781046526/overview/', '/vehicledetail/detail/775819985/overview/', '/vehicledetail/detail/780309506/overview/', '/vehicledetail/detail/771171587/overview/', '/vehicledetail/detail/780029643/overview/', '/vehicledetail/detail/775983996/overview/', '/vehicledetail/detail/774290605/overview/', '/vehicledetail/detail/780403890/overview/', '/vehicledetail/detail/780568473/overview/', '/vehicledetail/detail/777102832/overview/', '/vehicledetail/detail/769608676/overview/', '/vehicledetail/detail/778982650/overview/', '/vehicledetail/detail/764467625/overview/', '/vehicledetail/detail/780814189/overview/', '/vehicledetail/detail/757268846/overview/', '/vehicledetail/detail/754660601/overview/', '/vehicledetail/detail/779925650/overview/', '/vehicledetail/detail/781093669/overview/', '/vehicledetail/detail/761222401/overview/', '/vehicledetail/detail/763680832/overview/', '/vehicledetail/detail/770817425/overview/', '/vehicledetail/detail/769322895/overview/', '/vehicledetail/detail/771150423/overview/', '/vehicledetail/detail/772138016/overview/', '/vehicledetail/detail/781259627/overview/', '/vehicledetail/detail/774079654/overview/', '/vehicledetail/detail/783413897/overview/', '/vehicledetail/detail/774865168/overvi ...

# %%
new_url=[]
for i in url:
    complete_list=(f'https://www.cars.com'+i)
    new_url.append(complete_list)
print(len(new_url))
# Out:
# 150

# %%
# Now that the urls for each individual vehicle have been found use the fetch_page_and_convert_to_bs() function...
# each pass of the loop should scrape the pertinent data points from the page
# each scrape should store the data points as a dictionary

final_data=[]

def get_car_info(url):
        response = requests.get(url)
        soup = bs(response.text, 'html.parser')
        # Delay 5 seconds before returning the soup object to prevent Python from sending too many requests in a rapid succession    
        time.sleep(3)

        return soup  
    
    
for url in new_url:
    soup=get_car_info(url)
    
    #Confirms that the listing includes 
    try:
        year_make_model = soup.find('p', class_ = 'mmy-link').a.text
        year_make_model_list = year_make_model.split()
        list_len=len(year_make_model_list)
        #Evaluates that all required data elements have been supplied but checking the greatest index element.
        mileage = soup.find_all('li', class_ = 'vdp-details-basics__item')[10].span.text

    except:
        list_len=0

    
    if list_len==3:

        year=year_make_model_list[0]
        make=year_make_model_list[1]
        model=year_make_model_list[2]

        condition = soup.find('h1', class_ = 'vehicle-info__stock-type').text
        condition = condition.title()
        price = soup.find('span', class_='vehicle-info__price-display').text
        vin = soup.find_all('li', class_ = 'vdp-details-basics__item')[9].span.text
        mileage = soup.find_all('li', class_ = 'vdp-details-basics__item')[10].span.text
        transmission = soup.find_all('li', class_ = 'vdp-details-basics__item')[7].span.text
        engine = soup.find_all('li', class_ = 'vdp-details-basics__item')[8].span.text
        drive_type = soup.find_all('li', class_ = 'vdp-details-basics__item')[6].span.text
        fuel_type = soup.find_all('li', class_ = 'vdp-details-basics__item')[0].span.text
        exterior_color = soup.find_all('li', class_ = 'vdp-details-basics__item')[1].span.text
        interior_color = soup.find_all('li', class_ = 'vdp-details-basics__item')[3].span.text
        seller_name = soup.find('h3', class_ = 'vdp-dealer-info__title').text
        seller_address = soup.find('p', class_ = 'vdp-dealer-location__address').text
        
        #Parsing address field to extract zip code
        address_parts = seller_address.split()
        where_to_pull=len(address_parts)
        zip_code = address_parts[where_to_pull-1]
        
        vehicle = {
        'condition' : condition,
        'price' : price,
        'drive_type' : drive_type,
        'engine' : engine,
        'seller_name' : seller_name,
        'zip' : zip_code,
        'fuel_type' : fuel_type,
        'exterior_color' : exterior_color,
        'interior_color' : interior_color,
        'mileage' : mileage,
        'transmission' : transmission,
        'vin' : vin,
        'url' : url

        }
        
        final_data.append(vehicle)
        
        print(condition, year, make, model)
        print(price)
        print(drive_type)
        print(engine)
        print(seller_name, zip_code)
        print(fuel_type)
        print(exterior_color)
        print(interior_color)
        print(mileage)
        print(transmission)
        print(vin)
        print(url)
# Out:
# New 2019 Ford F-150
# $46,040
#  RWD
#  2.7L V6 24V PDI DOHC Twin Turbo
# Randall Reed's Prestige Ford 75041
#  Gasoline
#  Oxford White
#  Medium Earth Gray
#  3
#  Automatic
#  1FTEW1CP7KKE31574
# https://www.cars.com/vehicledetail/detail/782675683/overview/
# {'condition': 'New', 'price': '$46,040', 'drive_type': ' RWD', 'engine': ' 2.7L V6 24V PDI DOHC Twin Turbo', 'seller_name': "Randall Reed's Prestige Ford", 'zip': '75041', 'fuel_type': ' Gasoline', 'exterior_color': ' Oxford White', 'interior_color': ' Medium Earth Gray', 'mileage': ' 3', 'transmission': ' Automatic', 'vin': ' 1FTEW1CP7KKE31574', 'url': 'https://www.cars.com/vehicledetail/detail/782675683/overview/'}
# New 2019 Ford F-150
# $41,040
#  RWD
#  2.7L V6 24V PDI DOHC Twin Turbo
# Randall Reed's Prestige Ford 75041
#  Gasoline
#  White
#  Black
#  3,095
#  Automatic
#  1FTEW1CP7KKC66657
# https://www.cars.com/vehicledetail/detail/782874496/overview/
# {'condition': 'New', 'price': '$46,040', 'drive_type': ' RWD', 'engine': ' 2.7L V6 24V PDI DOHC Twin Turbo', 'seller_name': "Randall Reed's Prestige Ford", 'zip': '75041', 'fuel_type': ' Gasoline', 'exterior_color': ' Oxford White', 'interior_color': ' Medium Earth Gray', 'mileage': ' 3', 'transmission': ' Automatic', 'vin': ' 1FTEW1CP7KKE31574', 'url': 'https://www.cars.com/vehicledetail/detail/782675683/overview/'}
# New 2020 Chevrolet Traverse
# $35,405
#  FWD
#  3.6L V6 24V GDI DOHC
# Jupiter Chevrolet Inc 75041
#  Gasoline
#  Silver Ice Metallic
#  Jet Black
#  5
#  9-Speed Automatic
#  1GNERGKW9LJ117197
# https://www.cars.com/vehicledetail/detail/780786905/overview/
# {'condition': 'New', 'price': '$46,040', 'drive_type': ' RWD', 'engine': ' 2.7L V6 24V PDI DOHC Twin Turbo', 'seller_name': "Randall Reed's Prestige Ford", 'zip': '75041', 'fuel_type': ' Gasoline', 'exterior_color': ' Oxford White', 'interior_color': ' Medium Earth Gray', 'mileage': ' 3', 'transmission': ' Automatic', 'vin': ' 1FTEW1CP7KKE31574', 'url': 'https://www.cars.com/vehicledetail/detail/782675683/overview/'}
# New 2019 Toyota Prius
# $26,103
#  FWD
#  1.8L I4 16V MPFI DOHC Hybrid
# Sport City Toyota 75228
#  Hybrid
#  Blizzard Pearl
#  Beige
#  Not provided
#  Automatic CVT
#  JTDKARFU3K3095949
# https://www.cars.com/vehicledetail/detail/782110566/overview/
# {'condition': 'New', 'price': '$46,040', 'drive_type': ' RWD', 'engine': ' 2.7L V6 24V PDI DOHC Twin Turbo', 'seller_name': "Randall Reed's Prestige Ford", 'zip': '75041', 'fuel_type': ' Gasoline', 'exterior_color': ' Oxford White', 'interior_color': ' Medium Earth Gray', 'mileage': ' 3', 'transmission': ' Automatic', 'vin': ' 1FTEW1CP7KKE31574', 'url': 'https://www.cars.com/vehicledetail/detail/782675683/overview/'}
# New 2019 Ford Ranger
# $32,305
#  RWD
#  2.3L I4 16V GDI DOHC Turbo
# Randall Reed's Prestige Ford 75041
#  Gasoline
#  Ingot Silver Metallic
#  Ebony
#  23
#  10-Speed Automatic
#  1FTER4EH7KLA48677
# https://www.cars.com/vehicledetail/detail/774253853/overview/
# {'condition': 'New', 'price': '$46,040', 'drive_type': ' RWD', 'engine': ' 2.7L V6 24V PDI DOHC Twin Turbo', 'seller_name': "Randall Reed's Prestige Ford", 'zip': '75041', 'fuel_type': ' Gasoline', 'exterior_color': ' Oxford White', 'interior_color': ' Medium Earth Gray', 'mileage': ' 3', 'transmission': ' Automatic', 'vin': ' 1FTEW1CP7KKE31574', 'url': 'https://www.cars.com/vehicledetail/detail/782675683/overview/'}
# New 2019 Toyota Tundra
# $41,997
#  4WD
#  5.7L V8 32V MPFI DOHC
# Sport City Toyota 75228
#  Gasoline
#  Super White
#  Graphite
#  Not provided
#  6-Speed Automatic
#  5TFDY5F11KX850317
# https://www.cars.com/vehicledetail/detail/775693455/overview/
# {'condition': 'New', 'price': '$46,040', 'drive_type': ' RWD', 'engine': ' 2.7L V6 24V PDI DOHC Twin Turbo', 'seller_name': "Randall Reed's Prestige Ford", 'zip': '75041', 'fuel_type': ' Gasoline', 'exterior_color': ' Oxford White', 'interior_color': ' Medium Earth Gray', 'mileage': ' 3', 'transmission': ' Automatic', 'vin': ' 1FTEW1CP7KKE31574', 'url': 'https://www.cars.com/vehicledetail/detail/782675683/overview/'}
# New 2019 Honda CR-V
# $31,878
#  FWD
#  1.5L I4 DOHC 16V
# Rusty Wallis Honda 75228
#  Gasoline
#  Gunmetal
#  Gray
#  5
#  CVT
#  7FARW1H96KE016016
# https://www.cars.com/vehicledetail/detail/771301441/overview/
# {'condition': 'New', 'price': '$46,040', 'drive_type': ' RWD', 'engine': ' 2.7L V6 24V PDI DOHC Twin Turbo', 'seller_name': "Randall Reed's Prestige Ford", 'zip': '75041', 'fuel_type': ' Gasoline', 'exterior_color': ' Oxford White', 'interior_color': ' Medium Earth Gray', 'mileage': ' 3', 'transmission': ' Automatic', 'vin': ' 1FTEW1CP7KKE31574', 'url': 'https://www.cars.com/vehicledetail/detail/782675683/overview/'}
# New 2019 Honda Ridgeline
# $34,969
#  FWD
#  3.5L V6 SOHC i-VTEC 24V
# Rusty Wallis Honda 75228
#  Gasoline
#  White Diamond
#  Beige/
#  9
#  6-Speed Automatic
#  5FPYK2F6XKB006842
# https://www.cars.com/vehicledetail/detail/772928320/overview/
# {'condition': 'New', 'price': '$46,040', 'drive_type': ' RWD', 'engine': ' 2.7L V6 24V PDI DOHC Twin Turbo', 'seller_name': "Randall Reed's Prestige Ford", 'zip': '75041', 'fuel_type': ' Gasoline', 'exterior_color': ' Oxford White', 'interior_color': ' Medium Earth Gray', 'mileage': ' 3', 'transmission': ' Automatic', 'vin': ' 1FTEW1CP7KKE31574', 'url': 'https://www.cars.com/vehicledetail/detail/782675683/overview/'}
# New 2019 Ford F-150
# $38,742
#  RWD
#  2.7L V6 24V PDI DOHC Twin Turbo
# North Central Ford 75080
#  Gasoline
#  Magnetic Gray
#  Medium Earth Gray
#  11
#  Automatic
#  1FTEW1CP8KKD69621
# https://www.cars.com/vehicledetail/detail/772428590/overview/
# {'condition': 'New', 'price': '$46,040', 'drive_type': ' RWD', 'engine': ' 2.7L V6 24V PDI DOHC Twin Turbo', 'seller_name': "Randall Reed's Prestige Ford", 'zip': '75041', 'fuel_type': ' Gasoline', 'exterior_color': ' Oxford White', 'interior_color': ' Medium Earth Gray', 'mileage': ' 3', 'transmission': ' Automatic', 'vin': ' 1FTEW1CP7KKE31574', 'url': 'https://www.cars.com/vehicledetail/detail/782675683/overview/'}
# New 2019 Chevrolet Colorado
# $36,920
#  RWD
#  3.6L V6 24V GDI DOHC
# Reliable Chevrolet 75080
#  Gasoline
#  Summit White
#  Jet Black
#  18
#  Automatic
#  1GCGSCEN6K1269390
# https://www.cars.com/vehicledetail/detail/767362885/overview/
# {'condition': 'New', 'price': '$46,040', 'drive_type': ' RWD', 'engine': ' 2.7L V6 24V PDI DOHC Twin Turbo', 'seller_name': "Randall Reed's Prestige Ford", 'zip': '75041', 'fuel_type': ' Gasoline', 'exterior_color': ' Oxford White', 'interior_color': ' Medium Earth Gray', 'mileage': ' 3', 'transmission': ' Automatic', 'vin': ' 1FTEW1CP7KKE31574', 'url': 'https://www.cars.com/vehicledetail/detail/782675683/overview/'}
# New 2019 Toyota Highlander
# $36,857
#  FWD
#  3.5L V6 24V PDI DOHC
# Toyota of Richardson 75080
#  Gasoline
#  Blizzard Pearl
#  Black
#  2
#  8-Speed Automatic
#  5TDKZRFH6KS334842
# https://www.cars.com/vehicledetail/detail/775382273/overview/
# {'condition': 'New', 'price': '$46,040', 'drive_type': ' RWD', 'engine': ' 2.7L V6 24V PDI DOHC Twin Turbo', 'seller_name': "Randall Reed's Prestige Ford", 'zip': '75041', 'fuel_type': ' Gasoline', 'exterior_color': ' Oxford White', 'interior_color': ' Medium Earth Gray', 'mileage': ' 3', 'transmission': ' Automatic', 'vin': ' 1FTEW1CP7KKE31574', 'url': 'https://www.cars.com/vehicledetail/detail/782675683/overview/'}
# New 2019 Nissan Titan
# $46,488
#  4WD
#  5.6L V8 32V GDI DOHC
# Courtesy Nissan 75080
#  Gasoline
#  Magnetic Black
#  Beige
#  44
#  7-Speed Automatic
#  1N6AA1E59KN508675
# https://www.cars.com/vehicledetail/detail/762192909/overview/
# {'condition': 'New', 'price': '$46,040', 'drive_type': ' RWD', 'engine': ' 2.7L V6 24V PDI DOHC Twin Turbo', 'seller_name': "Randall Reed's Prestige Ford", 'zip': '75041', 'fuel_type': ' Gasoline', 'exterior_color': ' Oxford White', 'interior_color': ' Medium Earth Gray', 'mileage': ' 3', 'transmission': ' Automatic', 'vin': ' 1FTEW1CP7KKE31574', 'url': 'https://www.cars.com/vehicledetail/detail/782675683/overview/'}
# New 2020 Chevrolet Traverse
# $49,490
#  FWD
#  3.6L V6 24V GDI DOHC
# Reliable Chevrolet 75080
#  Gasoline
#  Summit White
#  Jet Black
#  3
#  9-Speed Automatic
#  1GNERKKW3LJ126464
# https://www.cars.com/vehicledetail/detail/781551588/overview/
# {'condition': 'New', 'price': '$46,040', 'drive_type': ' RWD', 'engine': ' 2.7L V6 24V PDI DOHC Twin Turbo', 'seller_name': "Randall Reed's Prestige Ford", 'zip': '75041', 'fuel_type': ' Gasoline', 'exterior_color': ' Oxford White', 'interior_color': ' Medium Earth Gray', 'mileage': ' 3', 'transmission': ' Automatic', 'vin': ' 1FTEW1CP7KKE31574', 'url': 'https://www.cars.com/vehicledetail/detail/782675683/overview/'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-5018e5e61498> in <module>
#      16
#      17 for url in new_url:
# ---> 18     soup=get_car_info(url)
#      19
#      20     #Confirms that the listing includes
#
# <ipython-input-9-5018e5e61498> in get_car_info(url)
#      10         soup = bs(response.text, 'html.parser')
#      11         # Delay 5 seconds before returning the soup object to prevent Python from sending too many requests in a rapid succession
# ---> 12         time.sleep(3)
#      13
#      14         return soup
#
# KeyboardInterrupt:
