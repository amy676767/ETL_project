# %%
import requests, time
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
def fetch_page_and_convert_to_bs(url):

    response = requests.get(url)
    soup = bs(response.text, 'html.parser')
    
    # Delay 5 seconds before returning the soup object to prevent Python from sending too many requests in a rapid succession
    
    time.sleep(5)

    return soup

def get_vehicle_urls():
    
    counter = 1
    iterate = True
    pages = 0
    vehicle_urls = []
    
    # Storing the base url the data will be fetched from

    base_url = 'https://www.ebay.com/b/Cars-Trucks/6001?UF_context=finderType%3AVEHICLE_FINDER&rt=nc&_from=R40&_pgn='

    # Running a loop to determine how many pages with vehicle content exist
    
    while (iterate): # replace "pages == 0" with "iterate"
        
        """ 
            Creating a dynamic url that will update the page number in each pass of the loop
            until there is no vehicle content to be found
        """

        url = f'{base_url}{counter}'
        
        # Instantiating a beautiful soup object to store the html
        
        soup = fetch_page_and_convert_to_bs(url)        
        
        # Identify if any vehicles exist

        has_vehicle = bool(len(soup.find('a', class_ = 's-item__link')))
        
        # Scrap 3 pages worth of data
        
        if (has_vehicle and pages < 2 ):
            
            pages += 1
            counter += 1
            
            # Find all the vehicles that exist on the page
            
            vehicles = soup.find_all('a', class_ = 's-item__link')
            
            for vehicle in vehicles:
                vehicle_urls.append(vehicle['href'])
        else:
            iterate = False
            return vehicle_urls

# %%
urls = get_vehicle_urls()
print(urls)
# Out:
# ['https://www.ebay.com/itm/1968-Chevrolet-Camaro/223573084084?hash=item340dfe87b4:g:VMkAAOSwcN5c7B5M', 'https://www.ebay.com/itm/2018-Ford-Mustang-Cobra-Jet/383118299712?hash=item5933a15240:g:8VYAAOSwp1BdYEGK', 'https://www.ebay.com/itm/2007-Ford-Mustang-Shelby-GT500/293176318200?hash=item4442ab98f8:g:63sAAOSwpPpdRbQY', 'https://www.ebay.com/itm/1970-Chevrolet-Corvette/303245303215?hash=item469ad41daf:g:~8IAAOSwlPhdSH~r', 'https://www.ebay.com/itm/1955-Chevrolet-Other-Pickups-1st-Series-Pickup-RESTORED/254319460633?hash=item3b369f0119:g:d7kAAOSwyWddRa-Y', 'https://www.ebay.com/itm/1958-Chevrolet-Other-Pickups-Truck/283565552156?hash=item4205d2f21c:g:rw4AAOSwdNBdQNtC', 'https://www.ebay.com/itm/2019-Ford-F-150-Raptor/123872707374?hash=item1cd763832e:g:NCwAAOSwTa1c5AfJ', 'https://www.ebay.com/itm/1998-Ford-Mustang/293179867562?hash=item4442e1c1aa:g:AGUAAOSwR11dSd0h', 'https://www.ebay.com/itm/2019-Ford-Mustang-GT/133147944903?hash=item1f003c67c7:g:NrkAAOSwTUZdUzJ4', 'https://www.ebay.com/itm/2004-Ford-Mustang-Premium-Mach-1/293176351687?hash=item4442ac1bc7:g:PIIAAOSwV3BdEYB4', 'https://www.ebay.com/itm/2019-Ford-F-150-Raptor/133149938718?hash=item1f005ad41e:g:yrcAAOSwq25cp6JD', 'https://www.ebay.com/itm/2015-Ford-Mustang-GT-Premium-5-0-Convertible/293176336406?hash=item4442abe016:g:E3QAAOSwvPtdRbvP', 'https://www.ebay.com/itm/1971-Chevrolet-Corvette-LS5/223603349985?hash=item340fcc59e1:g:IhsAAOSwTUZdPeID', 'https://www.ebay.com/itm/1942-Ford-Other/273955598785?hash=item3fc906b1c1:g:M~gAAOSwn~hdRySB', 'https://www.ebay.com/itm/1969-Chevrolet-Corvette/303263734750?hash=item469bed5bde:g:9VcAAOSwrf9dYeot', 'https://www.ebay.com/itm/2008-Ford-Other/113839664876?hash=item1a815f6eec:g:9h8AAOSwUpJdQ1uQ', 'https://www.ebay.com/itm/1969-Chevrolet-Camaro-Yenko/293194279358?hash=item4443bda9be:g:pNMAAOSwAgVdM56t', 'https://www.ebay.com/itm/2013-Chevrolet-Camaro-ZL1-2dr-Coupe/223610689343?hash=item34103c573f:g:UXgAAOSwOI5dReKT', 'https://www.ebay.com/itm/2018-Chevrolet-Corvette/202749146065?hash=item2f34ca73d1:g:7SoAAOSwlQhdRgSS', 'https://www.ebay.com/itm/2019-Ford-Mustang-Bullitt/133149941127?hash=item1f005add87:g:ZbEAAOSw1fZdYGjg', 'https://www.ebay.com/itm/2012-Chevrolet-Corvette-Z16-Grand-Sport-3LT/293176325142?hash=item4442abb416:g:w-wAAOSwPRldRbe1', 'https://www.ebay.com/itm/2007-Chevrolet-Corvette-Z06-Cammed-With-Many-Upgrades/293175693840?hash=item4442a21210:g:abEAAOSwuzldEYDG', 'https://www.ebay.com/itm/2013-Ford-Mustang-GT-Premium-Kenne-Bell-Supercharged/293176327360?hash=item4442abbcc0:g:o7cAAOSwPDBdRbig', 'https://www.ebay.com/itm/1968-Chevrolet-Impala-custom/273958044182?hash=item3fc92c0216:g:Tb4AAOSwS4ddQG28', 'https://www.ebay.com/itm/2013-Ford-F150-FX4/293176343433?hash=item4442abfb89:g:8HsAAOSwqz1dCxnL', 'https://www.ebay.com/itm/2019-Ford-Mustang-Shelby-GT350R/133149936306?hash=item1f005acab2:g:JxIAAOSwwJhdUt6Z', 'https://www.ebay.com/itm/2015-Ford-Mustang-GT-Premium-5-0/293176344074?hash=item4442abfe0a:g:E38AAOSwOwJdCxs-', 'https://www.ebay.com/itm/1969-Chevrolet-Camaro-ZL-1/153607478937?hash=item23c3b81e99:g:w~IAAOSwMRJcjG8k', 'https://www.ebay.com/itm/1967-Chevrolet-Nova/233306988012?hash=item36522e1dec:g:vHcAAOSwqaNcXzkF', 'https://www.ebay.com/itm/2013-Chevrolet-Camaro-SS-1LE-With-Upgrades/293176517838?hash=item4442aea4ce:g:7x4AAOSww7ddRgYR', 'https://www.ebay.com/itm/1971-Chevrolet-Other-Pickups/202751551433?hash=item2f34ef27c9:g:lz4AAOSwI2NdSpdd', 'https://www.ebay.com/itm/2019-Ford-F-150-Platinum/133149940143?hash=item1f005ad9af:g:p~cAAOSwrlddYGhc', 'https://www.ebay.com/itm/1969-Chevrolet-Corvette-L46-350-4-Speed-Matching-Numbers/254324869257?hash=item3b36f18889:g:IsgAAOSwNkxdTHa3', 'https://www.ebay.com/itm/2011-Toyota-FJ-Cruiser-Base/264426746259?hash=item3d910ff193:g:SIEAAOSwJTddJ2wS', 'https://www.ebay.com/itm/1966-Chevrolet-Corvette-Coupe-427/352741515340?hash=item522108604c:g:38kAAOSw1wZdFVhe', 'https://www.ebay.com/itm/2019-Ford-F-150-XLT/153616897644?hash=item23c447d66c:g:g5gAAOSwxgBdWtUQ', 'https://www.eb ...

# %%
# The next two lines are used for testing only

counter = 0
vehicles = []


# This list does not include "url", "condition", or "model" (all are defined below)

key_names = ['condition', 'drive_type', 'engine', 'exterior_color', 'fuel_type', \
             'interior_color', 'make', 'mileage', 'model', 'price',  \
             'seller_name', 'source_id', 'transmission', 'url', 'vin', 'year'
]

for url in urls:
    
    vehicle = {}

    soup = fetch_page_and_convert_to_bs(url)

    try:
        condition = soup.find('div', class_ = 'nonActPanel').div.find_all('div')[1].text

    except AttributeError as error:
        condition = None

    try:
        price = soup.find('span', {'itemprop' : 'price'}).text

    except AttributeError as error:
        price = None        

    try:
        model = soup.find('h2',  {'itemprop' : 'model'}).text

    except AttributeError as error:
        model = None

    # The element with the id: "itemSellerDesc" is an additional section that "sometimes" exists...
    # checking for this element to determine which index position will contain the table that stores the attributes    

    item_attr_div = soup.find('div', class_ = 'itemAttr')
    does_item_specifics_tbl_exist = bool(soup.find('table', {"id":'itmSellerDesc'}))

    # Target the table that stores the vehicle attributes and store the rows

    if (does_item_specifics_tbl_exist):

        table = item_attr_div.find_all('table')[1]

    else:

        table = item_attr_div.find_all('table')[0]

    attr_labels = table.find_all('td', class_ = 'attrLabels')
    attr_values = table.find_all('span')
    clean_labels = []
    clean_values = []

    for label in attr_labels:

        clean_label = label.text.strip() \
            .replace(':','') \
            .replace(' ', '_') \
            .lower()

        if (clean_label == 'model'):
            continue

        elif (clean_label == 'vin_(vehicle_identification_number)'):
            new_vin_label = clean_label.replace('vin_(vehicle_identification_number)', 'vin')
            clean_labels.append(new_vin_label)

        elif (clean_label == 'for_sale_by'):
            new_seller_label = clean_label.replace('for_sale_by', 'seller_name')
            clean_labels.append(new_seller_label)                    

        else:                
            clean_labels.append(clean_label)

    for value in attr_values:
        clean_values.append(value.text)


    for x in range(len(clean_labels)):
        vehicle[clean_labels[x]] = clean_values[x]

    vehicle['price'] = price        
    vehicle['url'] = url
    vehicle['condition'] = condition
    vehicle['model'] = model
    vehicle['source_id'] = 0

    # Adding the required keys

    for key in key_names:
        if (key not in vehicle):
            vehicle[key] = None

    # Removing unrequired keys

    vehicle = {k: vehicle[k] for k in key_names}

    vehicles.append(vehicle)

# %%
print(vehicles)
# Out:
# [{'condition': 'Used', 'drive_type': 'RWD', 'engine': '327', 'exterior_color': 'Red', 'fuel_type': 'Gasoline', 'interior_color': 'Black', 'make': 'Chevrolet', 'mileage': '67225', 'model': 'Camaro', 'price': 'US $22,999.00', 'seller_name': 'Dealer', 'source_id': 0, 'transmission': 'Manual', 'url': 'https://www.ebay.com/itm/1968-Chevrolet-Camaro/223573084084?hash=item340dfe87b4:g:VMkAAOSwcN5c7B5M', 'vin': '124378N312077', 'year': '1968'}, {'condition': 'New', 'drive_type': None, 'engine': '5.2L supercharge', 'exterior_color': None, 'fuel_type': None, 'interior_color': None, 'make': 'Ford', 'mileage': '2', 'model': 'Mustang', 'price': 'US $179,000.00', 'seller_name': None, 'source_id': 0, 'transmission': None, 'url': 'https://www.ebay.com/itm/2018-Ford-Mustang-Cobra-Jet/383118299712?hash=item5933a15240:g:8VYAAOSwp1BdYEGK', 'vin': '1FA6P8JZ0K5550988', 'year': '2018'}, {'condition': 'Used', 'drive_type': None, 'engine': '5.4L 32-VALVE SUPERCHARGED V8 ENGINE', 'exterior_color': 'White', 'fuel_type': 'Gasoline', 'interior_color': 'Black', 'make': 'Ford', 'mileage': '24996', 'model': 'Mustang', 'price': 'US $28,991.00', 'seller_name': 'Dealer', 'source_id': 0, 'transmission': 'Manual', 'url': 'https://www.ebay.com/itm/2007-Ford-Mustang-Shelby-GT500/293176318200?hash=item4442ab98f8:g:63sAAOSwpPpdRbQY', 'vin': '1ZVHT88S675315135', 'year': '2007'}, {'condition': 'Used', 'drive_type': 'RWD', 'engine': '454', 'exterior_color': 'Gray', 'fuel_type': 'Gasoline', 'interior_color': 'Black', 'make': 'Chevrolet', 'mileage': '999999', 'model': 'Corvette', 'price': 'US $7,975.00', 'seller_name': 'Private Seller', 'source_id': 0, 'transmission': 'Automatic', 'url': 'https://www.ebay.com/itm/1970-Chevrolet-Corvette/303245303215?hash=item469ad41daf:g:~8IAAOSwlPhdSH~r', 'vin': '194370S406512', 'year': '1970'}, {'condition': 'Used', 'drive_type': None, 'engine': 'Inline 6', 'exterior_color': 'Red', 'fuel_type': 'Gasoline', 'interior_color': 'Black', 'make': 'Chevrolet', 'mileage': '0', 'model': 'Other Pickups', 'price': 'US $27,500.00', 'seller_name': 'Dealer', 'source_id': 0, 'transmission': 'Manual', 'url': 'https://www.ebay.com/itm/1955-Chevrolet-Other-Pickups-1st-Series-Pickup-RESTORED/254319460633?hash=item3b369f0119:g:d7kAAOSwyWddRa-Y', 'vin': 'H55S008410', 'year': '1955'}, {'condition': 'Used', 'drive_type': 'RWD', 'engine': '350 V8', 'exterior_color': 'Gray', 'fuel_type': 'Gasoline', 'interior_color': 'Black', 'make': 'Chevrolet', 'mileage': '41617', 'model': 'Other Pickups', 'price': 'US $11,000.00', 'seller_name': 'Private Seller', 'source_id': 0, 'transmission': 'Automatic', 'url': 'https://www.ebay.com/itm/1958-Chevrolet-Other-Pickups-Truck/283565552156?hash=item4205d2f21c:g:rw4AAOSwdNBdQNtC', 'vin': '3A58S102003', 'year': '1958'}, {'condition': 'New', 'drive_type': "Raptor 4WD SuperCrew 5.5' Box", 'engine': '5.0L Ford Coyote V8', 'exterior_color': 'White', 'fuel_type': 'Gasoline', 'interior_color': 'Black', 'make': 'Ford', 'mileage': '25', 'model': 'F-150', 'price': 'US $154,995.00', 'seller_name': 'Private Seller', 'source_id': 0, 'transmission': '10-Speed', 'url': 'https://www.ebay.com/itm/2019-Ford-F-150-Raptor/123872707374?hash=item1cd763832e:g:NCwAAOSwTa1c5AfJ', 'vin': '1FTFW1RG8KFA62082', 'year': '2019'}, {'condition': 'Certified pre-owned', 'drive_type': 'RWD', 'engine': '4.6', 'exterior_color': 'Yellow', 'fuel_type': 'Gasoline', 'interior_color': 'Black', 'make': 'Ford', 'mileage': '146000', 'model': 'Mustang', 'price': 'US $9,900.00', 'seller_name': 'Private Seller', 'source_id': 0, 'transmission': 'Manual', 'url': 'https://www.ebay.com/itm/1998-Ford-Mustang/293179867562?hash=item4442e1c1aa:g:AGUAAOSwR11dSd0h', 'vin': '1FAFP47V3WF208724', 'year': '1998'}, {'condition': 'New', 'drive_type': 'Rear Wheel Drive', 'engine': '5L 8 Cylinder Engine', 'exterior_color': 'White', 'fuel_type': 'Gasoline', 'interior_color': 'Black', 'make': 'Ford', 'mileage': '110', 'model': 'Mustang', 'price': 'US $21,699.00', 'seller_name': 'Dealer', 'source_ ...

# %%
df = pd.DataFrame(vehicles)

df.head()
# Out:
#   condition drive_type                                engine exterior_color  \
# 0      Used        RWD                                   327            Red
# 1       New       None                      5.2L supercharge           None
# 2      Used       None  5.4L 32-VALVE SUPERCHARGED V8 ENGINE          White
# 3      Used        RWD                                   454           Gray
# 4      Used       None                              Inline 6            Red
#
#   fuel_type interior_color       make mileage          model           price  \
# 0  Gasoline          Black  Chevrolet   67225         Camaro   US $22,999.00
# 1      None           None       Ford       2        Mustang  US $179,000.00
# 2  Gasoline          Black       Ford   24996        Mustang   US $28,991.00
# 3  Gasoline          Black  Chevrolet  999999       Corvette    US $7,975.00
# 4  Gasoline          Black  Chevrolet       0  Other Pickups   US $27,500.00
#
#       seller_name  source_id transmission  \
# 0          Dealer          0       Manual
# 1            None          0         None
# 2          Dealer          0       Manual
# 3  Private Seller          0    Automatic
# 4          Dealer          0       Manual
#
#                                                  url                vin  year
# 0  https://www.ebay.com/itm/1968-Chevrolet-Camaro...      124378N312077  1968
# 1  https://www.ebay.com/itm/2018-Ford-Mustang-Cob...  1FA6P8JZ0K5550988  2018
# 2  https://www.ebay.com/itm/2007-Ford-Mustang-She...  1ZVHT88S675315135  2007
# 3  https://www.ebay.com/itm/1970-Chevrolet-Corvet...      194370S406512  1970
# 4  https://www.ebay.com/itm/1955-Chevrolet-Other-...         H55S008410  1955
